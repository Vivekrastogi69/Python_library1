# %% [markdown]
# # day 19

# %% [markdown]
# # Seaborn liberary part 2

# %% [markdown]
# # bar plot in seaborn liberary

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = sns.load_dataset("penguins")

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df1["island"]
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: object

# %%
sns.barplot(x = df1.island, y = df1.bill_length_mm)
plt.show()

# %% [markdown]
# # ak tarika or hota hai isa draw karna ka

# %%
sns.barplot(x = "island" , y = "bill_length_mm" ,data = df1)
plt.show()

# %% [markdown]
# # male female mai divde karna ka liya

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x = "island" , y = "bill_length_mm" ,data = df1 , hue = "sex")
plt.show()

# %%
sns.barplot(x = df1.island, y = df1.bill_length_mm , hue = "sex")
plt.show() # asa karka nahi hoga
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sns.barplot(x = df1.island, y = df1.bill_length_mm , hue = "sex")
#       2 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
# ...

# %% [markdown]
# # ORDER

# %%
order1 = ["Dream" , "Torgersen" , "Biscoe"]
sns.barplot(x= "island" , y = "bill_length_mm", data =df1 , hue = "sex" , order = order1)
plt.show()

# %% [markdown]
# # agar huma male femail ka order bhi change karna ho tho

# %%
order1 = ["Dream" , "Torgersen" , "Biscoe"]
sns.barplot(x= "island" , y = "bill_length_mm", data =df1 , hue = "sex" , 
            order = order1, hue_order = ["Female" , "Male"])
plt.show()

# %%
order1 = ["Dream" , "Torgersen" , "Biscoe"]
sns.barplot(x= "island" , y = "bill_length_mm", data =df1 , color = "green")
plt.show()

# %%
# colour change karna catogorical data mai jo huna devide kara hai

# %%
sns.barplot(x= "island" , y = "bill_length_mm" , data = df1 , hue = "sex" , palette = "Accent")
plt.show()

# %%
sns.barplot(x = "island" , y = "bill_length_mm" , data = df1 , hue = "sex" , palette = "prism")
plt.show()

# %%
sns.barplot(x = "island" , y = "bill_length_mm" , data = df1 , hue = "sex" , palette = "gist_earth")
plt.show()

# %% [markdown]
# # saturation parameter

# %% [markdown]
# # colour dark ya light karna ka liya

# %%
sns.barplot(x = "island" , y = "bill_length_mm" , data = df1 , hue = "sex" , 
            palette = "prism",saturation = 0.3)
plt.show()

# %%
sns.barplot(x = "island" , y = "bill_length_mm" , data = df1 , hue = "sex" , 
            palette = "prism",saturation = 0.50)
plt.show()

# %% [markdown]
# # Histogram in seaborn liberary

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# df1

# %%
sns.displot(df1["flipper_length_mm"])
plt.show()

# %% [markdown]
# # ab yha dhak raha hai yha proper gab nahi hai 170 _ 180 ....... ya karna ka liya asa karta hai

# %% [markdown]
# # bins parameter use kara ga

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240])
plt.show()

# %% [markdown]
# # color

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240],
           color = "g")
plt.show()

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240],
           color = "r")
plt.show()

# %% [markdown]
# # kernal density = kde

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240,250,260] , kde = True)
plt.show()

# %% [markdown]
# # agar kde nahi chiya tho ------ kde = False ----- kar data hai

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240,250,260] , kde = False)
plt.show()
