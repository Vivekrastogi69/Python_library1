# %% [markdown]
# # pands day 15

# %% [markdown]
# # Part 2

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
 b = df['Name'][0:10] # slicing

# %%
b
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(b)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Agar indax apni marji sa set karna chata hai tho asa karta hai

# %%
l = ['swati' ,'a2','a3','a4','a5','a5','a7','a8','a9','a10']

# %%
pd.Series(b, index = l)
# Out:
# swati    NaN
# a2       NaN
# a3       NaN
# a4       NaN
# a5       NaN
# a5       NaN
# a7       NaN
# a8       NaN
# a9       NaN
# a10      NaN
# Name: Name, dtype: object

# %% [markdown]
# # ab hum dhak raha hai upar wala code mai NAN aa raha hai iski janga ham passanger ka name chiya tho hum nicha wala code ki thra kara ga

# %%
pd.Series(list(b), index =l)
# Out:
# swati                              Braund, Mr. Owen Harris
# a2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# a3                                  Heikkinen, Miss. Laina
# a4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# a5                                Allen, Mr. William Henry
# a5                                        Moran, Mr. James
# a7                                 McCarthy, Mr. Timothy J
# a8                          Palsson, Master. Gosta Leonard
# a9       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# a10                    Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
m1 = pd.Series([100,200,300,400,500], index = [1,2,3,4,5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([600,700,800,900,1000], index = [1,2,3,4,5])

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %% [markdown]
# # agar ya jo humna data frame banaye hai unha jorna chata hai tho asa karta hai

# %%
m3 = pd.concat([m1,m2])

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1] # Agar hama pata karna ho ki kis index pa kya hai tho asa karta hai
# Out:
# 1    100
# 1    600
# dtype: int64

# %% [markdown]
# # agar dono ko multiply karna ho tho asa kara ga

# %%
m1*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %% [markdown]
# # addition ka liya

# %%
m1+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Agar koi column delete karna ho tho asa karta hai

# %%
df.drop("PassengerId" , axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # ab hum dhak raha hai wapas sa a gya agar hum parmannent liy dlete darna chata hai tho asa karta hai nicha wala code ki thara

# %%
df.drop("Survived", axis = 1 , inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # Agar row delete karna chata hai tho asa karta hai

# %%
# 3rd row ko delet karyta hai
df.drop(3)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
# abhi parmanntly delete nahi hua hai prtmannent delet karna ka liya
df.drop(3, inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
# Agar ak sa jajda lkarna chata ho tho

# %%
df.drop([0,1], inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 2              3       3                    Heikkinen, Miss. Laina  female
# 4              5       3                  Allen, Mr. William Henry    male
# 5              6       3                          Moran, Mr. James    male
# 6              7       1                   McCarthy, Mr. Timothy J    male
# 7              8       3            Palsson, Master. Gosta Leonard    male
# ..           ...     ...                                       ...     ...
# 886          887       2                     Montvila, Rev. Juozas    male
# 887          888       1              Graham, Miss. Margaret Edith  female
# 888          889       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890       1                     Behr, Mr. Karl Howell    male
# 890          891       3                       Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 2            3       3          Heikkinen, Miss. Laina  female  26.0      0
# 4            5       3        Allen, Mr. William Henry    male  35.0      0
# 5            6       3                Moran, Mr. James    male   NaN      0
# 6            7       1         McCarthy, Mr. Timothy J    male  54.0      0
# 7            8       3  Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S

# %% [markdown]
# # Agar hum chata hai ki ya jo hamara name hai wo hi indax ban jaye tho iska liya ya kara ga

# %%
# particular colum ko index banata hai
df.set_index("Name")
# Out:
#                                           PassengerId  Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                              3       3  female  26.0
# Allen, Mr. William Henry                            5       3    male  35.0
# Moran, Mr. James                                    6       3    male   NaN
# McCarthy, Mr. Timothy J                             7       1    male  54.0
# Palsson, Master. Gosta Leonard                      8       3    male   2.0
# ...                                               ...     ...     ...   ...
# Montvila, Rev. Juozas                             887       2    male  27.0
# Graham, Miss. Margaret Edith                      888       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"          889       3  female   NaN
# Behr, Mr. Karl Howell                             890       1    male  26.0
# Dooley, Mr. Patrick                               891       3    male  32.0
#
# ...

# %%
df
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 2              3       3                    Heikkinen, Miss. Laina  female
# 4              5       3                  Allen, Mr. William Henry    male
# 5              6       3                          Moran, Mr. James    male
# 6              7       1                   McCarthy, Mr. Timothy J    male
# 7              8       3            Palsson, Master. Gosta Leonard    male
# ..           ...     ...                                       ...     ...
# 886          887       2                     Montvila, Rev. Juozas    male
# 887          888       1              Graham, Miss. Margaret Edith  female
# 888          889       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890       1                     Behr, Mr. Karl Howell    male
# 890          891       3                       Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # ya properly nahi hua hai agar hum properly karna chata hai tho ya kara ga

# %%
df.set_index("Name", inplace = True)

# %%
df
# Out:
#                                           PassengerId  Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                              3       3  female  26.0
# Allen, Mr. William Henry                            5       3    male  35.0
# Moran, Mr. James                                    6       3    male   NaN
# McCarthy, Mr. Timothy J                             7       1    male  54.0
# Palsson, Master. Gosta Leonard                      8       3    male   2.0
# ...                                               ...     ...     ...   ...
# Montvila, Rev. Juozas                             887       2    male  27.0
# Graham, Miss. Margaret Edith                      888       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"          889       3  female   NaN
# Behr, Mr. Karl Howell                             890       1    male  26.0
# Dooley, Mr. Patrick                               891       3    male  32.0
#
# ...

# %%
df # dhakta hi permanent hua hai ya nahi
# Out:
#                                           PassengerId  Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                              3       3  female  26.0
# Allen, Mr. William Henry                            5       3    male  35.0
# Moran, Mr. James                                    6       3    male   NaN
# McCarthy, Mr. Timothy J                             7       1    male  54.0
# Palsson, Master. Gosta Leonard                      8       3    male   2.0
# ...                                               ...     ...     ...   ...
# Montvila, Rev. Juozas                             887       2    male  27.0
# Graham, Miss. Margaret Edith                      888       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"          889       3  female   NaN
# Behr, Mr. Karl Howell                             890       1    male  26.0
# Dooley, Mr. Patrick                               891       3    male  32.0
#
# ...

# %% [markdown]
# # index ko reset asa karta hai

# %%
df.reset_index()
# Out:
#                                          Name  PassengerId  Pclass     Sex  \
# 0                      Heikkinen, Miss. Laina            3       3  female
# 1                    Allen, Mr. William Henry            5       3    male
# 2                            Moran, Mr. James            6       3    male
# 3                     McCarthy, Mr. Timothy J            7       1    male
# 4              Palsson, Master. Gosta Leonard            8       3    male
# ..                                        ...          ...     ...     ...
# 883                     Montvila, Rev. Juozas          887       2    male
# 884              Graham, Miss. Margaret Edith          888       1  female
# 885  Johnston, Miss. Catherine Helen "Carrie"          889       3  female
# 886                     Behr, Mr. Karl Howell          890       1    male
# 887                       Dooley, Mr. Patrick          891       3    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#                                           PassengerId  Pclass     Sex   Age  \
# Name
# Heikkinen, Miss. Laina                              3       3  female  26.0
# Allen, Mr. William Henry                            5       3    male  35.0
# Moran, Mr. James                                    6       3    male   NaN
# McCarthy, Mr. Timothy J                             7       1    male  54.0
# Palsson, Master. Gosta Leonard                      8       3    male   2.0
# ...                                               ...     ...     ...   ...
# Montvila, Rev. Juozas                             887       2    male  27.0
# Graham, Miss. Margaret Edith                      888       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"          889       3  female   NaN
# Behr, Mr. Karl Howell                             890       1    male  26.0
# Dooley, Mr. Patrick                               891       3    male  32.0
#
# ...

# %% [markdown]
# # properly reset karna ka liya

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                          Name  PassengerId  Pclass     Sex  \
# 0                      Heikkinen, Miss. Laina            3       3  female
# 1                    Allen, Mr. William Henry            5       3    male
# 2                            Moran, Mr. James            6       3    male
# 3                     McCarthy, Mr. Timothy J            7       1    male
# 4              Palsson, Master. Gosta Leonard            8       3    male
# ..                                        ...          ...     ...     ...
# 883                     Montvila, Rev. Juozas          887       2    male
# 884              Graham, Miss. Margaret Edith          888       1  female
# 885  Johnston, Miss. Catherine Helen "Carrie"          889       3  female
# 886                     Behr, Mr. Karl Howell          890       1    male
# 887                       Dooley, Mr. Patrick          891       3    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#                                          Name  PassengerId  Pclass     Sex  \
# 0                      Heikkinen, Miss. Laina            3       3  female
# 1                    Allen, Mr. William Henry            5       3    male
# 2                            Moran, Mr. James            6       3    male
# 3                     McCarthy, Mr. Timothy J            7       1    male
# 4              Palsson, Master. Gosta Leonard            8       3    male
# ..                                        ...          ...     ...     ...
# 883                     Montvila, Rev. Juozas          887       2    male
# 884              Graham, Miss. Margaret Edith          888       1  female
# 885  Johnston, Miss. Catherine Helen "Carrie"          889       3  female
# 886                     Behr, Mr. Karl Howell          890       1    male
# 887                       Dooley, Mr. Patrick          891       3    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Dictionary sai data frame banana hai

# %% [markdown]
# # making a data frame from dictionary

# %%
d = { "key1" : [1,2,3,4,5],
      "key2" : [6,7,8,9,10],
      "key3" : [99,33,44,55,"vivek"]
    }

# %%
print(d)
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 10], 'key3': [99, 33, 44, 55, 'vivek']}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2   key3
# 0     1     6     99
# 1     2     7     33
# 2     3     8     44
# 3     4     9     55
# 4     5    10  vivek
